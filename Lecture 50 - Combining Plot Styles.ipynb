# %%
import pandas as pd
import numpy as np
from numpy.random import randn
import warnings
warnings.filterwarnings('ignore')
from scipy import stats
import matplotlib as mpt
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
dataset = randn(100)

# %%
sns.distplot(dataset,bins=25)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.distplot(dataset, bins=25,rug=True,hist=False)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.distplot(dataset,bins=25,
            kde_kws={'color':'indianred','label':'KDE Plot'},
            hist_kws={'color':'purple','label':'HIST Plot'})
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
from pandas import Series

series = Series(dataset,name='My_data')
series
# Out:
# 0    -0.222911
# 1     0.283110
# 2     0.714277
# 3    -0.555361
# 4     0.655407
#         ...
# 95   -0.941912
# 96   -0.876464
# 97   -0.369251
# 98   -0.183836
# 99    0.033131
# Name: My_data, Length: 100, dtype: float64

# %%
sns.distplot(series, bins=25)
# Out:
# <AxesSubplot:xlabel='My_data', ylabel='Density'>
