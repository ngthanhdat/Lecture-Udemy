# %%
import pandas as pd
import numpy as np
from numpy.random import randn
import warnings
warnings.filterwarnings('ignore')

# %%
from scipy import stats

# %%
import matplotlib as mpt
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
dataset1 = randn(100)

# %%
plt.hist(dataset1)
# Out:
# (array([ 4.,  7.,  6., 21., 26.,  6., 14.,  8.,  3.,  5.]),
#  array([-2.2712078 , -1.79743715, -1.3236665 , -0.84989585, -0.3761252 ,
#          0.09764545,  0.57141609,  1.04518674,  1.51895739,  1.99272804,
#          2.46649869]),
#  <BarContainer object of 10 artists>)

# %%
dataset2 = randn(80)

# %%
plt.hist(dataset2, color='skyblue')
# Out:
# (array([ 3., 14., 16.,  9., 16.,  7.,  7.,  5.,  2.,  1.]),
#  array([-1.51225886, -1.08590233, -0.6595458 , -0.23318927,  0.19316725,
#          0.61952378,  1.04588031,  1.47223684,  1.89859336,  2.32494989,
#          2.75130642]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(dataset1,density=True,color='skyblue', alpha=0.5, bins=20)  # normed replaced density
plt.hist(dataset2,density=True,alpha=0.5,bins=20)
# Out:
# (array([0.05863637, 0.11727274, 0.52772735, 0.29318186, 0.52772735,
#         0.4104546 , 0.35181823, 0.17590912, 0.46909098, 0.46909098,
#         0.35181823, 0.05863637, 0.17590912, 0.23454549, 0.11727274,
#         0.17590912, 0.05863637, 0.05863637, 0.        , 0.05863637]),
#  array([-1.51225886, -1.29908059, -1.08590233, -0.87272407, -0.6595458 ,
#         -0.44636754, -0.23318927, -0.02001101,  0.19316725,  0.40634552,
#          0.61952378,  0.83270205,  1.04588031,  1.25905857,  1.47223684,
#          1.6854151 ,  1.89859336,  2.11177163,  2.32494989,  2.53812816,
#          2.75130642]),
#  <BarContainer object of 20 artists>)

# %%
data1 = randn(1000)
data2 = randn(1000)

# %%
sns.jointplot(data1, data2)

# %%
sns.jointplot(data1, data2, kind='hex')
